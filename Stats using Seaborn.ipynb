# %% [markdown]
# ### Total Number of plots ###

# %% [markdown]
# * seaborn offers around 20+ distinct plot types,with variations in how you can adjust  them for specific tasks.

# %% [markdown]
#  * Here's is how

# %% [markdown]
# 1 Relational Plots(2 types).

# %% [markdown]
# 2 Categorical Plots(7 types)

# %% [markdown]
# 3 Distribution Plots( 4 types)

# %% [markdown]
# 4 Matrix Plots(2 typesṁ)

# %% [markdown]
# 5 Facet Plots( 3types)

# %% [markdown]
# 6 Time Series(1 type)

# %% [markdown]
# 7 Utility Plots(3 types)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\marot\Documents\data.csv")
df.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %% [markdown]
# ### Relational Plots ###

# %% [markdown]
# * 1 Scatter Plot *

# %% [markdown]
# * 2.Line Plot

# %%
# 1.Scatter Plot
#Plot individual data points on  a 2D Plane.

# %%
sns.scatterplot(x=df['BirthRate'],y=df['InternetUsers'],hue='IncomeGroup',data=df)
# Out:
# <Axes: xlabel='BirthRate', ylabel='InternetUsers'>

# %%
#--------Categorical Plots(7 types)
# 1Box Plot.
#2.Strip Plot
#3.Swarn Plot
#4 Swarn Plot
#5.Barplot
#6CountPlot
#7.Point Plot

# %%
# 1.Boxplot
# Display distribution with quartiles and Potential outliers.
sns.boxplot(x=df['BirthRate'],y=df['InternetUsers'],hue='IncomeGroup',data=df)
# Out:
# <Axes: xlabel='BirthRate', ylabel='InternetUsers'>

# %%
#3.Strip Plot
#Displays individual data points as dots.
sns.stripplot(x=df['BirthRate'],y=df['InternetUsers'],hue='IncomeGroup',data=df)
# Out:
# <Axes: xlabel='BirthRate', ylabel='InternetUsers'>

# %%
# 4.Swarm Plot
#Similar to a strip plot but avoids overlapping points.
sns.swarmplot(x=df['BirthRate'],y=df['InternetUsers'],hue='IncomeGroup',data=df)
# Out:
# C:\Users\marot\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 33.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\marot\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 25.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\marot\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 20.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='BirthRate', ylabel='InternetUsers'>

# %%
#5.Barplot 
#Shows the mean of a  continuos variable for each category.
sns.barplot(x=df['BirthRate'],y=df['InternetUsers'],hue='IncomeGroup',data=df)
# Out:
# <Axes: xlabel='BirthRate', ylabel='InternetUsers'>

# %%
# 4.CountPlot
#Display the  count of occurrences of each category.
sns.countplot(x=df['BirthRate'],hue='IncomeGroup',data=df)
# Out:
# <Axes: xlabel='BirthRate', ylabel='count'>

# %%
# 4.Count Plot
# Displays the count of occurrences of each category
sns.pointplot(x=df['BirthRate'],y=df['InternetUsers'],hue='IncomeGroup',data=df)
# Out:
# <Axes: xlabel='BirthRate', ylabel='InternetUsers'>

# %%
#----Distribution Plots(4 types)----
# 1.Histogram
#2.kernel Desn
